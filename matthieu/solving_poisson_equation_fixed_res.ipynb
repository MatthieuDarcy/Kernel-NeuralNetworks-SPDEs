# %% [markdown]
# # Solving the Poisson equation

# %%
from utilities_kernel_matern import *
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Untitled-1.ipynb Cell 2 line 1
# ----> <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#W3sdW50aXRsZWQ%3D?line=0'>1</a> from utilities_kernel_matern import *
#
# ModuleNotFoundError: No module named 'utilities_kernel_matern'

# %%
bump_values = vmap_indicator(x, epsilon_values, loc_values)

for i, loc in enumerate(loc_values):
    plt.plot(x, bump_values[:, 0, i])
plt.title("Bump functions at different locations")
plt.show()
